# %%
#This is the code used to clean data in the experiment created by Harpreet Singh
#Numpy and Pandas are the libraries that will be used to clean the data
import pandas as pd
import numpy as np
#Change the file directory to wherever your file is
#This first piece of code is reading the columns I wish to look at
df = pd.read_csv('WRITE YOUR FILE DIRECTORY',usecols=['ID','Task_Order','JS_Task','Buttons1','GMBM_Set','Positive_Order',
                                               'Person_Task_Order','Buttons2','Sex assigned at birth','Your highest level of academic achievement','Age in years','BDIResult','GAD7Result','RRSResult','RBResult',
                                                      '1Shape','1Congruence','1RT','1Score',
                                                      '2Character','2Shape','2Congruence','2RT',
                                                      '2Score','catresp.keys','textbox_6.text','BDI_Total','GAD7_Total','RRS_Total','Rosenberg_Total',
                                                 'Cognitive_Total','Somatic_af_Total','Self_Pos_Word','TimeDur_POSself','Self_Neg_Word','TimeDur_NEGself','Other_Pos_Word',
                                                 'TimeDur_POSother','Other_Neg_Word','TimeDur_NEGother','G_me_RT_Matched','B_me_RT_Matched','G_other_RT_Matched','B_other_RT_Matched',
                                                 'Self_RT_Matched','Other_RT_Matched','G_me_RT_Mismatched','B_me_RT_Mismatched','G_other_RT_Mismatched','B_other_RT_Mismatched',
                                                 'Self_RT_Mismatched','Other_RT_Mismatched'])
#This helps to ensure cleanliness in the code since sex and age and education level permeate throughout the entirety of the data
# Temporary variable called Shifter since the shifter value seems to be changing for every participant, possibly due to the clock code at the beginning
shifter = -6118


if df['Task_Order'][0] == 0:
  df['Sex assigned at birth'] = df['Sex assigned at birth'].shift(shifter)
  df['Age in years'] = df['Age in years'].shift(shifter)
  df['Your highest level of academic achievement'] = df['Your highest level of academic achievement'].shift(shifter)

if df['Task_Order'][0] == 1:
  df['Sex assigned at birth'] = df['Sex assigned at birth'].shift(shifter)
  df['Age in years'] = df['Age in years'].shift(shifter)
  df['Your highest level of academic achievement'] = df['Your highest level of academic achievement'].shift(shifter)


# Drop rows that has NaN values on selected columnsm, this also helps to clean the data up so that there are no blank spaces
df3=df.dropna(subset=['ID','Task_Order','JS_Task','Buttons1','GMBM_Set','Positive_Order',
                                               'Person_Task_Order','Buttons2','Sex assigned at birth','Your highest level of academic achievement','Age in years','BDIResult','GAD7Result','RRSResult','RBResult',
                                                      '1Shape','1Congruence','1RT','1Score',
                                                      '2Character','2Shape','2Congruence','2RT',
                                                      '2Score','catresp.keys','textbox_6.text','BDI_Total','GAD7_Total','RRS_Total','Rosenberg_Total',
                                                 'Cognitive_Total','Somatic_af_Total','Self_Pos_Word','TimeDur_POSself','Self_Neg_Word','TimeDur_NEGself','Other_Pos_Word',
                                                 'TimeDur_POSother','Other_Neg_Word','TimeDur_NEGother','G_me_RT_Matched','B_me_RT_Matched','G_other_RT_Matched','B_other_RT_Matched',
                                                 'Self_RT_Matched','Other_RT_Matched','G_me_RT_Mismatched','B_me_RT_Mismatched','G_other_RT_Mismatched','B_other_RT_Mismatched',
                                                 'Self_RT_Mismatched','Other_RT_Mismatched'],how='all')


#Renaming columns into something sensible
from typing_extensions import Final
df3.rename(columns = {'BDIResult' : 'BDI Results','GAD7Result' : 'GAD-7 Results','RRSResult' : 'Rumination results','RBResult' : 'Rosenberg results',
                                                       'catresp.keys' : 'Health group', 'Sex assigned at birth' : 'SEX', 'Age in years' : 'Age',
                       'Your highest level of academic achievement' : 'Education', 'textbox_6.text' : 'Treatment'}, inplace = True)


#Renaming the shape variables into their meaning

if df3['JS_Task'][0] == 0:
  df3['1Shape'] = df3['1Shape'].replace(['images/Triangle.png','images/Square.png'],['Self','Stranger'])

if df3['JS_Task'][0] == 1:
  df3['1Shape'] = df3['1Shape'].replace(['images/Square.png','images/Triangle.png'],['Self','Stranger'])

if df3['JS_Task'][0] == 2:
  df3['1Shape'] = df3['1Shape'].replace(['images/Triangle.png','images/Square.png'],['Self','Stranger'])

if df3['JS_Task'][0] == 3:
  df3['1Shape'] = df3['1Shape'].replace(['images/Square.png','images/Triangle.png'],['Self','Stranger'])

if df3['GMBM_Set'][0] == 0:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 1:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 2:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 3:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 4:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 5:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 6:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 7:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 8:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 9:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 10:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 11:
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 12:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 13:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 14:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 15:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 16:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 17:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 18:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 19:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 20:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 21:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 22:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 23:
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 24:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 25:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 26:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 27:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 28:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 29:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Heptagon.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 30:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 31:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 32:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 33:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 34:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 35:
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Heptagon.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 36:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 37:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 38:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 39:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Circle.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 40:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 41:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Diamond.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 42:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 43:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Star.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Diamond.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 44:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 45:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Circle.png','images/Star.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 46:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_other','Bad_other'])

if df3['GMBM_Set'][0] == 47:
  df3['2Shape'] = df3['2Shape'].replace(['images/Heptagon.png','images/Diamond.png'],['Good_me','Bad_me'])
  df3['2Shape'] = df3['2Shape'].replace(['images/Star.png','images/Circle.png'],['Good_other','Bad_other'])


#Shift the columns up so that the data is neat and tidy
if df3['Task_Order'][0] == 0:
  df3['Health group'] = df3['Health group'].shift(-1)
  df3['BDI Results'] = df3['BDI Results'].shift(-1)
  df3['GAD-7 Results'] = df3['GAD-7 Results'].shift(-22)
  df3['Rumination results'] = df3['Rumination results'].shift(-29)
  df3['Rosenberg results'] = df3['Rosenberg results'].shift(-39)

  df3['1Shape'] = df3['1Shape'].shift(-49)
  df3['1Congruence'] = df3['1Congruence'].shift(-49)
  df3['1RT'] = df3['1RT'].shift(-49)
  df3['1Score'] = df3['1Score'].shift(-49)


  df3['2Character'] = df3['2Character'].shift(-349)
  df3['2Shape'] = df3['2Shape'].shift(-349)
  df3['2Congruence'] = df3['2Congruence'].shift(-349)
  df3['2RT'] = df3['2RT'].shift(-349)
  df3['2Score'] = df3['2Score'].shift(-349)

  df3['ID'] = df3['ID'].shift(-829)
  df3['BDI_Total'] = df3['BDI_Total'].shift(-829)
  df3['GAD7_Total'] = df3['GAD7_Total'].shift(-829)
  df3['RRS_Total'] = df3['RRS_Total'].shift(-829)
  df3['Rosenberg_Total'] = df3['Rosenberg_Total'].shift(-829)
  df3['Cognitive_Total'] = df3['Cognitive_Total'].shift(-829)
  df3['Somatic_af_Total'] = df3['Somatic_af_Total'].shift(-829)
  
  df3['Self_RT_Matched'] = df3['Self_RT_Matched'].shift(-829)
  df3['Other_RT_Matched'] = df3['Other_RT_Matched'].shift(-829)

  df3['Self_RT_Mismatched'] = df3['Self_RT_Mismatched'].shift(-829)
  df3['Other_RT_Mismatched'] = df3['Other_RT_Mismatched'].shift(-829)

  df3['G_me_RT_Matched'] = df3['G_me_RT_Matched'].shift(-829)
  df3['B_me_RT_Matched'] = df3['B_me_RT_Matched'].shift(-829)
  df3['G_other_RT_Matched'] = df3['G_other_RT_Matched'].shift(-829)
  df3['B_other_RT_Matched'] = df3['B_other_RT_Matched'].shift(-829)

  df3['G_me_RT_Mismatched'] = df3['G_me_RT_Mismatched'].shift(-829)
  df3['B_me_RT_Mismatched'] = df3['B_me_RT_Mismatched'].shift(-829)
  df3['G_other_RT_Mismatched'] = df3['G_other_RT_Mismatched'].shift(-829)
  df3['B_other_RT_Mismatched'] = df3['B_other_RT_Mismatched'].shift(-829)

if df3['Task_Order'][0] == 1:
  df3['Health group'] = df3['Health group'].shift(-1)
  df3['BDI Results'] = df3['BDI Results'].shift(-1)
  df3['GAD-7 Results'] = df3['GAD-7 Results'].shift(-22)
  df3['Rumination results'] = df3['Rumination results'].shift(-29)
  df3['Rosenberg results'] = df3['Rosenberg results'].shift(-39)
  df3['Treatment'] = df3['Treatment'].shift(-1)

  df3['1Shape'] = df3['1Shape'].shift(-549)
  df3['1Congruence'] = df3['1Congruence'].shift(-549)
  df3['1RT'] = df3['1RT'].shift(-549)
  df3['1Score'] = df3['1Score'].shift(-549)


  df3['2Character'] = df3['2Character'].shift(-69)
  df3['2Shape'] = df3['2Shape'].shift(-69)
  df3['2Congruence'] = df3['2Congruence'].shift(-69)
  df3['2RT'] = df3['2RT'].shift(-69)
  df3['2Score'] = df3['2Score'].shift(-69)

  df3['ID'] = df3['ID'].shift(-829)
  df3['BDI_Total'] = df3['BDI_Total'].shift(-829)
  df3['GAD7_Total'] = df3['GAD7_Total'].shift(-829)
  df3['RRS_Total'] = df3['RRS_Total'].shift(-829)
  df3['Rosenberg_Total'] = df3['Rosenberg_Total'].shift(-829)
  df3['Cognitive_Total'] = df3['Cognitive_Total'].shift(-829)
  df3['Somatic_af_Total'] = df3['Somatic_af_Total'].shift(-829)
  
  df3['Self_RT_Matched'] = df3['Self_RT_Matched'].shift(-829)
  df3['Other_RT_Matched'] = df3['Other_RT_Matched'].shift(-829)

  df3['Self_RT_Mismatched'] = df3['Self_RT_Mismatched'].shift(-829)
  df3['Other_RT_Mismatched'] = df3['Other_RT_Mismatched'].shift(-829)

  df3['G_me_RT_Matched'] = df3['G_me_RT_Matched'].shift(-829)
  df3['B_me_RT_Matched'] = df3['B_me_RT_Matched'].shift(-829)
  df3['G_other_RT_Matched'] = df3['G_other_RT_Matched'].shift(-829)
  df3['B_other_RT_Matched'] = df3['B_other_RT_Matched'].shift(-829)

  df3['G_me_RT_Mismatched'] = df3['G_me_RT_Mismatched'].shift(-829)
  df3['B_me_RT_Mismatched'] = df3['B_me_RT_Mismatched'].shift(-829)
  df3['G_other_RT_Mismatched'] = df3['G_other_RT_Mismatched'].shift(-829)
  df3['B_other_RT_Mismatched'] = df3['B_other_RT_Mismatched'].shift(-829)

#These if statements below are to ensure that the word attribution task presents neatly and clearly

if df3['Task_Order'][0] == 0 and df3['Person_Task_Order'][0] == 0 and df3['Positive_Order'][0] == 0:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-334)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-334)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-329)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-329)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-344)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-344)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-339)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-339)

if df3['Task_Order'][0] == 0 and df3['Person_Task_Order'][0] == 0 and df3['Positive_Order'][0] == 1:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-329)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-329)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-334)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-334)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-339)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-339)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-344)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-344)

if df3['Task_Order'][0] == 0 and df3['Person_Task_Order'][0] == 1 and df3['Positive_Order'][0] == 0:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-344)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-344)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-339)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-339)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-334)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-334)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-329)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-329)

if df3['Task_Order'][0] == 0 and df3['Person_Task_Order'][0] == 1 and df3['Positive_Order'][0] == 1:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-339)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-339)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-344)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-344)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-329)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-329)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-334)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-334)

if df3['Task_Order'][0] == 1 and df3['Person_Task_Order'][0] == 0 and df3['Positive_Order'][0] == 0:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-54)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-54)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-49)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-49)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-64)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-64)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-59)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-59)

if df3['Task_Order'][0] == 1 and df3['Person_Task_Order'][0] == 0 and df3['Positive_Order'][0] == 1:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-49)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-49)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-54)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-54)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-59)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-59)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-64)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-64)

if df3['Task_Order'][0] == 1 and df3['Person_Task_Order'][0] == 1 and df3['Positive_Order'][0] == 0:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-64)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-64)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-59)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-59)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-54)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-54)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-49)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-49)

if df3['Task_Order'][0] == 1 and df3['Person_Task_Order'][0] == 1 and df3['Positive_Order'][0] == 1:
  df3['Self_Neg_Word'] = df3['Self_Neg_Word'].shift(-59)
  df3['TimeDur_NEGself'] = df3['TimeDur_NEGself'].shift(-59)
  df3['TimeDur_POSself'] = df3['TimeDur_POSself'].shift(-64)
  df3['Self_Pos_Word'] = df3['Self_Pos_Word'].shift(-64)
  df3['TimeDur_NEGother'] = df3['TimeDur_NEGother'].shift(-49)
  df3['Other_Neg_Word'] = df3['Other_Neg_Word'].shift(-49)
  df3['Other_Pos_Word'] = df3['Other_Pos_Word'].shift(-54)
  df3['TimeDur_POSother'] = df3['TimeDur_POSother'].shift(-54)

#This creates a file name that is relevant to the data
FileName = (str(df3['ID'][0]) + str(df3['SEX'][0]) + str(df3["Age"][0]) + str(df3['Health group'][0]))
#Save file
df3.to_csv(r'sample_data/%s.csv'%FileName, index = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (2,6,45,47,103,122,155,174,316,317,349) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
