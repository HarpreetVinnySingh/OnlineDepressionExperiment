# %%
import numpy as np
import pandas as pd
import numpy as np
import math
import statistics
from math import nan, isnan
import glob
import os


#THIS CODE IS TO FIX THE ROSENBERG SCORING, data from the experiment only recorded the keypresses. This code works to convert those key-presses into their intended variables


path = '/content/drive/MyDrive/CData/'

all_files = glob.glob(path+'*.csv')

for filename in all_files:



  #Reading data
  df = pd.read_csv(filename,usecols=['ID','Task_Order','JS_Task','Buttons1','GMBM_Set','Positive_Order',
                                                'Person_Task_Order','Buttons2','SEX','Education','Age',
                                                        '1Shape','1Congruence','1RT','1Score',
                                                        '2Character','2Shape','2Congruence','2RT',
                                                        '2Score','Health group','Treatment','BDI_Total','GAD7_Total','RRS_Total','Rosenberg results',
                                                  'Cognitive_Total','Somatic_af_Total','G_me_RT_Matched','B_me_RT_Matched','G_other_RT_Matched','B_other_RT_Matched',
                                                  'Self_RT_Matched','Other_RT_Matched','TimeDur_POSself','TimeDur_NEGself','TimeDur_POSother','TimeDur_NEGother'])
  
  Rosenberg_Total2 = 0
  #Normal scoring
  if df['Rosenberg results'][0] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 3
  
  if df['Rosenberg results'][0] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 2

  if df['Rosenberg results'][0] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 1
  
  if df['Rosenberg results'][0] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 0


  if df['Rosenberg results'][2] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 3
  
  if df['Rosenberg results'][2] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 2

  if df['Rosenberg results'][2] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 1
  
  if df['Rosenberg results'][2] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 0



  if df['Rosenberg results'][3] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 3
  
  if df['Rosenberg results'][3] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 2

  if df['Rosenberg results'][3] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 1
  
  if df['Rosenberg results'][3] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 0


  if df['Rosenberg results'][6] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 3
  
  if df['Rosenberg results'][6] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 2

  if df['Rosenberg results'][6] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 1
  
  if df['Rosenberg results'][6] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 0


  if df['Rosenberg results'][9] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 3
  
  if df['Rosenberg results'][9] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 2

  if df['Rosenberg results'][9] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 1
  
  if df['Rosenberg results'][9] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 0


  #Reverse scoring
  if df['Rosenberg results'][1] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 0
  
  if df['Rosenberg results'][1] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 1

  if df['Rosenberg results'][1] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 2
  
  if df['Rosenberg results'][1] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 3


  if df['Rosenberg results'][4] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 0
  
  if df['Rosenberg results'][4] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 1

  if df['Rosenberg results'][4] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 2
  
  if df['Rosenberg results'][4] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 3


  if df['Rosenberg results'][5] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 0
  
  if df['Rosenberg results'][5] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 1

  if df['Rosenberg results'][5] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 2
  
  if df['Rosenberg results'][5] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 3


  if df['Rosenberg results'][7] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 0
  
  if df['Rosenberg results'][7] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 1

  if df['Rosenberg results'][7] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 2
  
  if df['Rosenberg results'][7] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 3


  if df['Rosenberg results'][8] == 1:
    Rosenberg_Total2 = Rosenberg_Total2 + 0
  
  if df['Rosenberg results'][8] == 2:
    Rosenberg_Total2 = Rosenberg_Total2 + 1

  if df['Rosenberg results'][8] == 3:
    Rosenberg_Total2 = Rosenberg_Total2 + 2
  
  if df['Rosenberg results'][8] == 4:
    Rosenberg_Total2 = Rosenberg_Total2 + 3
  
  df.insert(0, "Rosenberg_Total2",Rosenberg_Total2, True)

  df["Rosenberg_Total2"] = df["Rosenberg_Total2"].shift(-829)

  #This creates a file name that is relevant to the data
  FileName = (str('rc') + str(df['ID'][0]) + str(df['SEX'][0]) + str(df["Age"][0]) + str(df['Health group'][0]) +str('.csv'))
  #Save file
  df.to_csv(r'/content/drive/MyDrive/RCData/%s'%FileName, index = False)
